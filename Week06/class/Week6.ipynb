# %%
import paramiko
from getpass import getpass

# Create pass prompt
thePass = getpass(prompt="Enter your password: ")

# Host Info
host = "172.22.210.193"
port = "22"
username = "kali"
password = thePass

try:

    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect(host, port, username, password)
except paramiko.AuthenticationException:
    print("Authentication Failed")

# %%
# Run a Command
command = "ps -ef"

# Get the outpit from the command
stdin, stout, stderr = ssh.exec_command(command)

# Get results from output
lines = stout.readlines()
# print(lines)

# Convert the list to a string.
output = '@@@'.join(lines)
print(output)
# Out:
# UID          PID    PPID  C STIME TTY          TIME CMD
# @@@root           1       0  0 10:06 ?        00:00:02 /sbin/init splash
# @@@root           2       0  0 10:06 ?        00:00:00 [kthreadd]
# @@@root           3       2  0 10:06 ?        00:00:00 [rcu_gp]
# @@@root           4       2  0 10:06 ?        00:00:00 [rcu_par_gp]
# @@@root           6       2  0 10:06 ?        00:00:00 [kworker/0:0H-kblockd]
# @@@root           8       2  0 10:06 ?        00:00:00 [mm_percpu_wq]
# @@@root           9       2  0 10:06 ?        00:00:00 [ksoftirqd/0]
# @@@root          10       2  0 10:06 ?        00:00:01 [rcu_sched]
# @@@root          11       2  0 10:06 ?        00:00:00 [migration/0]
# @@@root          13       2  0 10:06 ?        00:00:00 [cpuhp/0]
# @@@root          14       2  0 10:06 ?        00:00:00 [cpuhp/1]
# @@@root          15       2  0 10:06 ?        00:00:00 [migration/1]
# @@@root          16       2  0 10:06 ?        00:00:00 [ksoftirqd/1]
# @@@root          18       2  0 10:06 ?        00:00:00 [kworker/1:0H]
# @@@root          19       2  0 10:06 ?        00:00:00 [cpuhp/2]
# @@@root          20       2  0 10:06 ?        00:00:00 [migration/2]
# @@@root          21       2  0 10:06 ?        00:00:00 [ksoftirqd/2]
# @@@root          23       2  0 10:06 ?        00:00:00 [kworker/2:0H]
# @@@root          24       2  0 10:06 ?        00:00:00 [cpuhp/3]
# @@@root          25       2  0 10:06 ?        00:00:00 [migration/3]
# @@@root          26       2  0 10:06 ?        00:00:00 [ksoftirqd/3]
# @@@root          28       2  0 10:06 ?        00:00:00 [kworker/3:0H-kblockd]
# @@@root          30       2  0 10:06 ?        00:00:00 [kdevtmpfs]
# @@@root          31       2  0 10:06 ?        00:00:00 [netns]
# @@@root          32       2  0 10:06 ?        00:00:00 [rcu_tasks_rude_]
# @@@root          33       2  0 10:06 ?        00:00:00 [kauditd]
# @@@root          39       2  0 10:06 ?        00:00:00 [khungtaskd]
# @@@root          40       2  0 10:06 ?        00:00:00 [oom_reaper]
# @@@root          41       2  0 10:06 ?        00:00:00 [writeback]
# @@@root          42       2  0 10:06 ?        00:00:00 [kcompactd0]
# @@@root          43       2  0 10:06 ?        00:00:00 [ksmd]
# @@@root          44       2  0 10:06 ?        00:00:00 [khugepaged]
# @@@root          62       2  0 10:06 ?        00:00:00 [kintegrityd]
# @@@root          63       2  0 10:06 ?        00:00:00 [kblockd]
# @@@root          64       2  0 10:06 ?        00:00:00 [blkcg_punt_bio]
# @@@root          65       2  0 10:06 ?        00:00:00 [edac-poller]
# @@@root          66       2  0 10:06 ?        00:00:00 [devfreq_wq]
# @@@root          69       2  0 10:06 ?        00:00:00 [kswapd0]
# @@@root          70       2  0 10:06 ?        00:00:00 [kthrotld]
# @@@root          71       2  0 10:06 ?        00:00:00 [irq/24-pciehp]
# @@@root          72       2  0 10:06 ?        00:00:00 [irq/25-pciehp]
# @@@root          73       2  0 10:06 ?        00:00:00 [irq/26-pciehp]
# @@@root          74       2  0 10:06 ?        00:00:00 [irq/27-pciehp]
# @@@root          75       2  0 10:06 ?        00:00:00 [irq/28-pciehp]
# @@@root          76       2  0 10:06 ?        00:00:00 [irq/29-pciehp]
# @@@root          77       2  0 10:06 ?        00:00:00 [irq/30-pciehp]
# @@@root          78       2  0 10:06 ?        00:00:00 [irq/31-pciehp]
# @@@root          79       2  0 10:06 ?        00:00:00 [irq/32-pciehp]
# @@@root          80       2  0 10:06 ?        00:00:00 [irq/33-pciehp]
# @@@root          81       2  0 10:06 ?        00:00:00 [irq/34-pciehp]
# @@@root          82       2  0 10:06 ?        00:00:00 [irq/35-pciehp]
# @@@root          83       2  0 10:06 ?        00:00:00 [irq/36-pciehp]
# @@@root          84       2  0 10:06 ?        00:00:00 [irq/37-pciehp]
# @@@root          85       2  0 10:06 ?        00:00:00 [irq/38-pciehp]
# @@@root          86       2  0 10:06 ?        00:00:00 [irq/39-pciehp]
# @@@root          87       2  0 10:06 ?        00:00:00 [irq/40-pciehp]
# @@@root          88       2  0 10:06 ?        00:00:00 [irq/41-pciehp]
# @@@root          89       2  0 10:06 ?        00:00:00 [irq/42-pciehp]
# @@@root          90       2  0 10:06 ?        00:00:00 [irq/43-pciehp]
# @@@root          91       2  0 10:06 ?        00:00:00 [irq/44-pciehp]
# @@@root          92       2  0 10:06 ?        00:00:00 [irq/45-pciehp]
# @@@root          93       2  0 10:06 ?        00:00:00 [irq/46-pciehp]
# @@@root          94       2  0 10:06 ?        00:00:00 [irq/47-pciehp]
# @@@root          95       2  0 10:06 ?        00:00:00 [irq/48-pciehp]
# @@@root          96       2  0 10:06 ?        00:00:00 [irq/49-pciehp]
# @@@root          97       2  0 10:06 ?        00:00:00 [irq/50-pciehp]
# @@@root          98       2  0 10:06 ?        00:00:00 [irq/51-pciehp]
# @@@root          99       2  0 10:06 ?        00:00:00 [irq/52-pciehp]
# @@@root         100       2  0 10:06 ?        00:00:00 [irq/53-pciehp]
# @@@root         101       2  0 10:06 ?        00:00:00 [irq/54-pciehp]
# @@@root         102       2  0 10:06 ?        00:00:00 [irq/55-pciehp]
# @@@root         103       2  0 10:06 ?        00:00:00 [acpi_thermal_pm]
# @@@root         104       2  0 10:06 ?        00:00:00 [ipv6_addrconf]
# @@@root         114       2  0 10:06 ?        00:00:00 [kstrp]
# @@@root         117       2  0 10:06 ?        00:00:00 [zswap-shrink]
# @@@root         118       2  0 10:06 ?        00:00:00 [kworker/u65:0]
# @@@root         161       2  0 10:06 ?        00:00:00 [ata_sff]
# @@@root         162       2  0 10:06 ?        00:00:00 [mpt_poll_0]
# @@@root         163       2  0 10:06 ?        00:00:00 [irq/16-vmwgfx]
# @@@root         164       2  0 10:06 ?        00:00:00 [scsi_eh_0]
# @@@root         165       2  0 10:06 ?        00:00:00 [ttm_swap]
# @@@root         166       2  0 10:06 ?        00:00:00 [scsi_tmf_0]
# @@@root         167       2  0 10:06 ?        00:00:00 [mpt/0]
# @@@root         168       2  0 10:06 ?        00:00:00 [card0-crtc0]
# @@@root         169       2  0 10:06 ?        00:00:00 [card0-crtc1]
# @@@root         170       2  0 10:06 ?        00:00:00 [scsi_eh_1]
# @@@root         171       2  0 10:06 ?        00:00:00 [card0-crtc2]
# @@@root         172       2  0 10:06 ?        00:00:00 [scsi_tmf_1]
# @@@root         173       2  0 10:06 ?        00:00:00 [card0-crtc3]
# @@@root         175       2  0 10:06 ?        00:00:00 [card0-crtc4]
# @@@root         176       2  0 10:06 ?        00:00:00 [card0-crtc5]
# @@@root         177       2  0 10:06 ?        00:00:00 [card0-crtc6]
# @@@root         178       2  0 10:06 ?        00:00:00 [card0-crtc7]
# @@@root         179       2  0 10:06 ?        00:00:00 [cryptd]
# @@@root         229       2  0 10:06 ?        00:00:00 [kworker/0:1H-kblockd]
# @@@root         230       2  0 10:06 ?        00:00:00 [scsi_eh_2]
# @@@root         231       2  0 10:06 ?        00:00:00 [scsi_tmf_2]
# @@@root         234       2  0 10:06 ?        00:00:00 [kworker/3:1H-kblockd]
# @@@root         235       2  0 10:06 ?        00:00:00 [kworker/1:1H-kblockd]
# @@@root         240       2  0 10:06 ?        00:00:00 [kworker/2:1H-kblockd]
# @@@root         280       2  0 10:06 ?        00:00:00 [jbd2/sda1-8]
# @@@root         281       2  0 10:06 ?        00:00:00 [ext4-rsv-conver]
# @@@root         324       1  0 10:06 ?        00:00:00 /lib/systemd/systemd-journald
# @@@root         337       2  0 10:06 ?        00:00:00 [rpciod]
# @@@root         338       2  0 10:06 ?        00:00:00 [xprtiod]
# @@@root         354       1  0 10:06 ?        00:00:01 /lib/systemd/systemd-udevd
# @@@root         355       1  0 10:06 ?        00:00:00 vmware-vmblock-fuse /run/vmblock-fuse -o rw,subtype=vmware-vmblock,default_permissions,allow_other,dev,suid
# @@@root         443       1  0 10:06 ?        00:00:00 /usr/sbin/haveged --Foreground --verbose=1 -w 1024
# @@@root         446       1  0 10:06 ?        00:00:11 /usr/bin/vmtoolsd
# @@@root         492       1  0 10:06 ?        00:00:00 /usr/sbin/cron -f
# @@@message+     493       1  0 10:06 ?        00:00:00 /usr/bin/dbus-daemon --system --address=systemd: --nofork --nopidfile --systemd-activation --syslog-only
# @@@root         494       1  0 10:06 ?        00:00:00 /usr/sbin/NetworkManager --no-daemon
# @@@root         497       1  0 10:06 ?        00:00:00 /usr/libexec/polkitd --no-debug
# @@@root         502       1  0 10:06 ?        00:00:00 /usr/sbin/smartd -n
# @@@root         505       1  0 10:06 ?        00:00:00 /lib/systemd/systemd-logind
# @@@root         558       1  0 10:06 ?        00:00:00 /usr/sbin/ModemManager
# @@@root         585       1  0 10:06 ?        00:00:00 /usr/sbin/lightdm
# @@@root         596     585  0 10:06 tty7     00:00:23 /usr/lib/xorg/Xorg :0 -seat seat0 -auth /var/run/lightdm/root/:0 -nolisten tcp vt7 -novtswitch
# @@@root         598       1  0 10:06 tty1     00:00:00 /sbin/agetty -o -p -- \u --noclear tty1 linux
# @@@rtkit        806       1  0 10:06 ?        00:00:00 /usr/libexec/rtkit-daemon
# @@@root         864     585  0 10:07 ?        00:00:00 lightdm --session-child 14 23
# @@@kali         869       1  0 10:08 ?        00:00:00 /lib/systemd/systemd --user
# @@@kali         870     869  0 10:08 ?        00:00:00 (sd-pam)
# @@@kali         889     869  0 10:08 ?        00:00:03 /usr/bin/pulseaudio --daemonize=no
# @@@kali         892       1  0 10:08 ?        00:00:00 /usr/bin/gnome-keyring-daemon --daemonize --login
# @@@kali         895     864  0 10:08 ?        00:00:00 xfce4-session
# @@@kali         905     869  0 10:08 ?        00:00:01 /usr/bin/dbus-daemon --session --address=systemd: --nofork --nopidfile --systemd-activation --syslog-only
# @@@kali         939     895  0 10:08 ?        00:00:00 /usr/bin/ssh-agent x-session-manager
# @@@kali         949     869  0 10:08 ?        00:00:00 /usr/libexec/at-spi-bus-launcher
# @@@kali         954     949  0 10:08 ?        00:00:00 /usr/bin/dbus-daemon --config-file=/usr/share/defaults/at-spi2/accessibility.conf --nofork --print-address 3
# @@@kali         958     869  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/xfconf/xfconfd
# @@@kali         964     869  0 10:08 ?        00:00:00 /usr/libexec/at-spi2-registryd --use-gnome-session
# @@@kali         970     869  0 10:08 ?        00:00:00 /usr/bin/gpg-agent --supervised
# @@@kali         972     895  0 10:08 ?        00:00:03 xfwm4
# @@@kali         975     869  0 10:08 ?        00:00:00 /usr/libexec/gvfsd
# @@@kali         980     869  0 10:08 ?        00:00:00 /usr/libexec/gvfsd-fuse /run/user/1000/gvfs -f
# @@@kali         997       1  0 10:08 ?        00:00:00 xfsettingsd
# @@@kali         998     895  0 10:08 ?        00:00:01 xfce4-panel
# @@@root        1001       1  0 10:08 ?        00:00:00 /usr/libexec/upowerd
# @@@kali        1018     998  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/panel/wrapper-2.0 /usr/lib/x86_64-linux-gnu/xfce4/panel/plugins/libwhiskermenu.so 1 14680071 whiskermenu Whisker Menu Show a menu to easily access installed applications
# @@@kali        1021     998  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/panel/wrapper-2.0 /usr/lib/x86_64-linux-gnu/xfce4/panel/plugins/libsystray.so 15 14680073 systray Notification Area Area where notification icons appear
# @@@kali        1022     998  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/panel/wrapper-2.0 /usr/lib/x86_64-linux-gnu/xfce4/panel/plugins/libstatusnotifier.so 16 14680074 statusnotifier Status Notifier Plugin Provides a panel area for status notifier items (application indicators)
# @@@kali        1023     998  0 10:08 ?        00:00:04 /usr/lib/x86_64-linux-gnu/xfce4/panel/wrapper-2.0 /usr/lib/x86_64-linux-gnu/xfce4/panel/plugins/libpulseaudio-plugin.so 17 14680075 pulseaudio PulseAudio Plugin Adjust the audio volume of the PulseAudio sound system
# @@@kali        1024     998  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/panel/wrapper-2.0 /usr/lib/x86_64-linux-gnu/xfce4/panel/plugins/libnotification-plugin.so 18 14680076 notification-plugin Notification Plugin Notification plugin for the Xfce panel
# @@@kali        1025     998  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/panel/wrapper-2.0 /usr/lib/x86_64-linux-gnu/xfce4/panel/plugins/libxfce4powermanager.so 19 14680077 power-manager-plugin Power Manager Plugin Display the battery levels of your devices and control the brightness of your display
# @@@kali        1026     895  0 10:08 ?        00:00:00 Thunar --daemon
# @@@kali        1027     998  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/panel/wrapper-2.0 /usr/lib/x86_64-linux-gnu/xfce4/panel/plugins/libactions.so 21 14680078 actions Action Buttons Log out, lock or other system actions
# @@@kali        1048     895  0 10:08 ?        00:00:01 xfdesktop
# @@@kali        1049     869  0 10:08 ?        00:00:00 /usr/lib/x86_64-linux-gnu/xfce4/notifyd/xfce4-notifyd
# @@@kali        1056     895  0 10:08 ?        00:00:00 nm-applet
# @@@kali        1059     895  0 10:08 ?        00:00:00 /usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1
# @@@kali        1064     895  0 10:08 ?        00:00:00 light-locker
# @@@kali        1071     869  0 10:08 ?        00:00:00 /usr/libexec/dconf-service
# @@@kali        1081       1  0 10:08 ?        00:00:00 xcape -e Super_L Control_L Escape
# @@@kali        1082     895  0 10:08 ?        00:00:00 xiccd
# @@@kali        1086     895  0 10:08 ?        00:00:00 /usr/bin/python3 /usr/bin/blueman-applet
# @@@colord      1094       1  0 10:08 ?        00:00:00 /usr/libexec/colord
# @@@kali        1095     895  0 10:08 ?        00:00:00 /usr/libexec/geoclue-2.0/demos/agent
# @@@kali        1106       1  0 10:08 ?        00:00:09 /usr/bin/vmtoolsd -n vmusr --blockFd 3
# @@@kali        1107       1  0 10:08 ?        00:00:00 xfce4-power-manager
# @@@kali        1120       1  0 10:08 ?        00:00:03 /usr/bin/qterminal
# @@@kali        1123     869  0 10:08 ?        00:00:00 /usr/libexec/gvfs-udisks2-volume-monitor
# @@@root        1145       1  0 10:08 ?        00:00:00 /usr/libexec/udisks2/udisksd
# @@@kali        1161     869  0 10:08 ?        00:00:00 /usr/libexec/gvfs-afc-volume-monitor
# @@@kali        1166     869  0 10:08 ?        00:00:00 /usr/libexec/gvfs-goa-volume-monitor
# @@@kali        1170     869  0 10:08 ?        00:00:00 /usr/libexec/gvfs-gphoto2-volume-monitor
# @@@kali        1174     869  0 10:08 ?        00:00:00 /usr/libexec/gvfs-mtp-volume-monitor
# @@@kali        1187     975  0 10:08 ?        00:00:00 /usr/libexec/gvfsd-trash --spawner :1.11 /org/gtk/gvfs/exec_spaw/0
# @@@kali        1194     869  0 10:08 ?        00:00:00 /usr/libexec/gvfsd-metadata
# @@@kali        1202       1  0 10:08 ?        00:00:00 /usr/bin/python3 /usr/bin/blueman-tray
# @@@kali        1212     869  0 10:08 ?        00:00:00 /usr/libexec/bluetooth/obexd
# @@@kali        1216    1120  0 10:08 pts/0    00:00:00 /usr/bin/zsh
# @@@kali        1234       1  0 10:08 ?        00:00:13 /opt/google/chrome/chrome
# @@@kali        1239    1234  0 10:08 ?        00:00:00 cat
# @@@kali        1240    1234  0 10:08 ?        00:00:00 cat
# @@@kali        1242    1234  0 10:08 ?        00:00:00 /opt/google/chrome/chrome --type=zygote --no-zygote-sandbox --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6,
# @@@kali        1243    1234  0 10:08 ?        00:00:00 /opt/google/chrome/chrome-sandbox /opt/google/chrome/chrome --type=zygote --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6,
# @@@kali        1244    1243  0 10:08 ?        00:00:00 /opt/google/chrome/chrome --type=zygote --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6,
# @@@kali        1246    1244  0 10:08 ?        00:00:00 /opt/google/chrome/chrome-sandbox /opt/google/chrome/nacl_helper
# @@@kali        1247    1246  0 10:08 ?        00:00:00 /opt/google/chrome/nacl_helper
# @@@kali        1249    1244  0 10:08 ?        00:00:00 /opt/google/chrome/chrome --type=zygote --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6,
# @@@kali        1266    1242  0 10:08 ?        00:00:56 /opt/google/chrome/chrome --type=gpu-process --field-trial-handle=15717444226247277413,14051603953171192212,131072 --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6, --gpu-preferences=QAAAAAAAAAAgAAAQAAAAAAAAAAAAAAAAAABgAAAAAAAgAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAA --shared-files
# @@@kali        1272    1234  0 10:08 ?        00:00:01 /opt/google/chrome/chrome --type=utility --utility-sub-type=network.mojom.NetworkService --field-trial-handle=15717444226247277413,14051603953171192212,131072 --lang=en-US --service-sandbox-type=network --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6, --shared-files=v8_context_snapshot_data:100
# @@@kali        1298    1249  0 10:08 ?        00:00:00 /opt/google/chrome/chrome --type=utility --utility-sub-type=storage.mojom.StorageService --field-trial-handle=15717444226247277413,14051603953171192212,131072 --lang=en-US --service-sandbox-type=utility --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6, --shared-files=v8_context_snapshot_data:100
# @@@kali        1305     869  0 10:08 ?        00:00:00 /usr/bin/gnome-keyring-daemon --start --foreground --components=secrets
# @@@kali        1526    1249  0 10:08 ?        00:00:07 /opt/google/chrome/chrome --type=renderer --field-trial-handle=15717444226247277413,14051603953171192212,131072 --lang=en-US --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6, --origin-trial-disabled-features=SecurePaymentConfirmation --num-raster-threads=2 --enable-main-frame-before-activation --renderer-client-id=24 --no-v8-untrusted-code-mitigations --shared-files=v8_context_snapshot_data:100
# @@@kali        1539    1249  0 10:08 ?        00:00:00 /opt/google/chrome/chrome --type=renderer --field-trial-handle=15717444226247277413,14051603953171192212,131072 --lang=en-US --enable-crash-reporter=1052d0d7-c668-4daa-bb96-0f7c9c7713a6, --origin-trial-disabled-features=SecurePaymentConfirmation --num-raster-threads=2 --enable-main-frame-before-activation --renderer-client-id=25 --no-v8-untrusted-code-mitigations --shared-files=v8_context_snapshot_data:100
# @@@root        1629    1216  0 10:10 pts/0    00:00:00 sudo su
# @@@root        1630    1629  0 10:10 pts/0    00:00:00 su
# @@@root        1631    1630  0 10:10 pts/0    00:00:02 zsh
# @@@root        2704    1631  0 10:17 pts/0    00:00:00 python3
# @@@root        2935       2  0 10:37 ?        00:00:00 [kworker/2:1-ata_sff]
# @@@root        3157       2  0 11:18 ?        00:00:00 [kworker/0:0-mm_percpu_wq]
# @@@root        3158       2  0 11:18 ?        00:00:00 [kworker/1:0-events]
# @@@root        3243       2  0 11:34 ?        00:00:00 [kworker/3:1-events]
# @@@root        3402       2  0 12:09 ?        00:00:00 [kworker/u64:1-ext4-rsv-conversion]
# @@@root        3422       2  0 12:11 ?        00:00:00 [kworker/3:2-events]
# @@@systemd+    3641       1  0 12:11 ?        00:00:00 /lib/systemd/systemd-networkd
# @@@root        3824       2  0 12:15 ?        00:00:00 [kworker/u64:0-flush-8:0]
# @@@root        3835       2  0 12:17 ?        00:00:00 [kworker/2:3-events]
# @@@root        4678       1  0 12:20 ?        00:00:00 /usr/sbin/rsyslogd -n -iNONE
# @@@root        4679       2  0 12:20 ?        00:00:00 [kworker/0:2-cgroup_destroy]
# @@@root        4719       2  0 12:20 ?        00:00:00 [kworker/1:1]
# @@@root        4756       1  0 12:22 ?        00:00:00 sshd: /usr/sbin/sshd -D [listener] 0 of 10-100 startups
# @@@root        4758    4756  0 12:22 ?        00:00:00 sshd: kali [priv]
# @@@kali        4764    4758  0 12:22 ?        00:00:00 sshd: kali
# @@@root        4765       2  0 12:22 ?        00:00:00 [kworker/2:0-ata_sff]
# @@@root        4767    4756  0 12:23 ?        00:00:00 sshd: kali [priv]
# @@@kali        4773    4767  0 12:23 ?        00:00:00 sshd: kali@notty
# @@@root        4775    4756  0 12:24 ?        00:00:00 sshd: kali [priv]
# @@@kali        4781    4775  0 12:24 ?        00:00:00 sshd: kali@notty
# @@@root        4789       2  0 12:25 ?        00:00:00 [kworker/u64:2]
# @@@kali        4792    4781  0 12:25 ?        00:00:00 ps -ef
